# %%
import pandas as pd
import numpy as np
import string

# %%
#FILE READING CELL 

df = pd.read_csv('../data/spam.csv', encoding='latin-1')
df = df[['v1', 'v2']]

# %%
#DEBUG CELL 01

df.columns = ['label', 'message']

print("===Total Values=====================================")
print(df['label'].value_counts)
print("====================================================")
# Out:
# ===Total Values=====================================
# <bound method IndexOpsMixin.value_counts of 0        ham
# 1        ham
# 2       spam
# 3        ham
# 4        ham
#         ...
# 5567    spam
# 5568     ham
# 5569     ham
# 5570     ham
# 5571     ham
# Name: label, Length: 5572, dtype: str>
# ====================================================

# %%
#FORMATTING THE DATA


from fnmatch import translate


df['label'] = df['label'].str.lower()
df['message'] = df['message'].str.lower()

sym = str.maketrans('' , '', string.punctuation)
print(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 11
#       7 df['label'] = df['label'].str.lower()
#       8 df['message'] = df['message'].str.lower()
#       9
#      10 sym = str.maketrans('' , '', string.punctuation)
# ---> 11 print(translate(sym))
#      12 # for i in df['messages']:
#      13 #     if i is in sym:
#      14 #         pass
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\fnmatch.py:85, in translate(pat)
#      83 i, n = 0, len(pat)
#      84 while i < n:
# ---> 85     c = pat[i]
#      86     i = i+1
#      87     if c == '*':
#      88         # compress consecutive `*` into one
#
# KeyError: 0
