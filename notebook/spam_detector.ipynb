# %%
import pandas as pd
import numpy as np
import string
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
#FILE READING CELL 

df = pd.read_csv('../data/spam.csv', encoding='latin-1')
df = df[['v1', 'v2']]

# %%
#DEBUG CELL 01

df.columns = ['label', 'message']

# print("===Total Values=====================================")
# print(df['label'].value_counts)
# print("====================================================")

# %%
#FORMATTING THE DATA


df['label'] = df['label'].str.lower()
df['message'] = df['message'].str.lower()

df['message'] = df['message'].str.replace(r'[^a-zA-Z0-9\s.]', '', regex=True)

# %%
# SPLITING, TRAINING AND TESTING DATA
# X = features (inputs), y = target (output)

x_train, x_test, y_train, y_test = train_test_split(df['message'], df['label'], test_size=0.2, random_state=42)

model = LogisticRegression()

tfid = TfidfVectorizer()
x_train = tfid.fit_transform(x_train)
x_test = tfid.transform(x_test)
y_train = y_train.map({'ham':1 , 'spam':0})
y_test = y_test.map({'ham':1 , 'spam':0})
model.fit(x_train, y_train)

prediction = model.predict(x_test)

accuracy = accuracy_score(y_test,prediction)

# %%
# BASIC ENGINE COMPLETE NOW CAN USE IT NOW MAKING UI OF ITS

# %%
print("======WELCOME TO SPAM DETECTOR=====================================")
message = input("Enter the message to check : ")
# Out:
# ======WELCOME TO SPAM DETECTOR=====================================
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 4
#       1 print("======WELCOME TO SPAM DETECTOR=====================================")
#       2 message = list(input("Enter the message to check : "))
#       3
# ----> 4 prob = model.predict(message)
#       5
#       6 if prob>0.5:
#       7     print("THE MESSAGE IS HAM")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:414, in LinearClassifierMixin.predict(self, X)
#     412 check_same_namespace(X, self, attribute="coef_", method="predict")
#     413 xp, _, device_ = get_namespace_and_device(X)
# --> 414 scores = self.decision_function(X)
#     415 if len(scores.shape) == 1:
#     416     indices = xp.astype(scores > 0, indexing_dtype(xp))
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_base.py:389, in LinearClassifierMixin.decision_function(self, X)
#     386 xp, _ = get_namespace(X)
#     387 check_same_namespace(X, self, attribute="coef_", method="decision_function")
# --> 389 X = validate_data(self, X, accept_sparse="csr", reset=False)
#     390 coef_T = self.coef_.T if self.coef_.ndim == 2 else self.coef_
#     391 scores = safe_sparse_dot(X, coef_T, dense_output=True) + self.intercept_
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:3038, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    3036         out = X, y
#    3037 elif not no_val_X and no_val_y:
# -> 3038     out = check_array(X, input_name="X", **check_params)
#    3039 elif no_val_X and not no_val_y:
#    3040     out = _check_y(y, **check_params)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1073, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_writeable, ensure_all_finite, ensure_non_negative, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1066         else:
#    1067             msg = (
#    1068                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1069                 "Reshape your data either using array.reshape(-1, 1) if "
#    1070                 "your data has a single feature or array.reshape(1, -1) "
#    1071                 "if it contains a single sample."
#    1072             )
# -> 1073         raise ValueError(msg)
#    1075 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1076     raise ValueError(
#    1077         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1078         "Convert your data to numeric values explicitly instead."
#    1079     )
#
# ValueError: Expected 2D array, got 1D array instead:
# array=['h' 'e' 'y' ' ' 'y' 'o' 'u' ' ' 'w' 'a' 'n' 't' ' ' 'a' ' ' 'f' 'r' 'e'
#  'e' ' ' 't' 'i' 'c' 'k' 'e' 't'].
# Reshape your data either using array.reshape(-1, 1) if your data has a single feature or array.reshape(1, -1) if it contains a single sample.
