# %%
import pandas as pd
import numpy as np
import string
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# Running cells with 'spam_message_detector (3.11.0) (Python 3.11.0)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: 'd:/spam_message_detector/.venv/Scripts/python.exe -m pip install ipykernel -U --force-reinstall'

# %%
#FILE READING CELL 

df = pd.read_csv('../data/spam.csv', encoding='latin-1')
df = df[['v1', 'v2']]

# %%
#DEBUG CELL 01

df.columns = ['label', 'message']

# print("===Total Values=====================================")
# print(df['label'].value_counts)
# print("====================================================")

# %%
#FORMATTING THE DATA


df['label'] = df['label'].str.lower()
df['message'] = df['message'].str.lower()

df['message'] = df['message'].str.replace(r'[^a-zA-Z0-9\s.]', '', regex=True)

# %%
# SPLITING, TRAINING AND TESTING DATA
# X = features (inputs), y = target (output)

x_train, x_test, y_train, y_test = train_test_split(df['message'], df['label'], test_size=0.2, random_state=42, stratify=df['label'])

model = LogisticRegression(class_weight='balanced')

tfid = TfidfVectorizer()
x_train = tfid.fit_transform(x_train)
x_test = tfid.transform(x_test)
y_train = y_train.map({'ham':1 , 'spam':0})
y_test = y_test.map({'ham':1 , 'spam':0})
model.fit(x_train, y_train)

prediction = model.predict(x_test)

accuracy = accuracy_score(y_test,prediction)

print(accuracy*100)
# Out:
# 98.02690582959642

# %%
# BASIC ENGINE COMPLETE NOW CAN USE IT NOW MAKING UI OF ITS

# %%
print("======WELCOME TO SPAM DETECTOR=====================================")
message = input("Enter the message to check : ")
message = [message]
translated = tfid.transform(message)
result = model.predict(translated)

if result == 0:
    print("This is a spam message.")
else:
    print("This is NOT a spam message.")
# Out:
# ======WELCOME TO SPAM DETECTOR=====================================
# This is NOT a spam message.
